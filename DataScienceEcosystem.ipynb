# %% [markdown]
# # Data Science Tools and Ecosystem
# <img
#      src   = "attachment:23652782-b436-4de7-adde-fa4f28f04a4a.png"
#      style = "width:200px;height:200px"
#      alt_text = "alt_text"
#      align = "left"
# />

# %% [markdown]
# ## Author:
# Dominic P.

# %% [markdown]
# #### In this notebook, Data Science Tools and Ecosystems are summarized.

# %% [markdown]
# Objectives:
# - Popular languages for Data Science
# - Common R-libraries
# - Common Data Science tools
# - Arithmetic examples in Python

# %% [markdown]
# Some of the popular languages that Data Scientist use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Scala
# 5. Julia
# 6. SAS

# %% [markdown]
# My language of choice is R. Here are some **common R-libraries** used by Data Scientist:
# |   Library   |   Description   |
# |-------|--------|
# |**ggplot2**|Primative graphs for data visualization|
# |**plotly**|Interactive and publish-ready graphs|
# |**caret**|Regression training and machine learning|
# |**SQLite**|Relational database management|
# |**markdown**|Create presentable reports|

# %% [markdown]
# In addition, the use of **data science tools** are important for completing tasks, here are some commonly used tools:
# |Tool|Description|
# |----|-----------|
# |Apache Spark|Data processing and analytics engine for large amounts of data|
# |Numpy|Python library used in data science and machine learning applications|
# |Jupyter Notebook|An open source web application that enables interactive collaboration|
# |Pandas|Python library used for data analysis and manipulation|
# |TensorFlow|Open source machine learning platform developed by Google|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This is a simple arithmetic expression to multiple then add integers
(3*4) + 5
# Out:
# 17

# %%
# This will convert minutes to hours by dividing by 60.
200 / 60
# Out:
# 3.3333333333333335
